# %%
from IPython.display import display
from PIL import Image

# INSERT_YOUR_CODE

from trdg.generators import (
    GeneratorFromDict,
    GeneratorFromRandom,
    GeneratorFromStrings,
    GeneratorFromWikipedia,
)

# The generators use the same arguments as the CLI, only as parameters
generator = GeneratorFromStrings(
    ['আমি যাবো', "নির্লজ্জ"],
    blur=2,
    random_blur=True,
    language="latin"
)

for i, (img, lbl) in enumerate(generator):
    display(img)
    if i > 10:
        break
# Out:
# <PIL.Image.Image image mode=RGB size=101x32>
# None
# <PIL.Image.Image image mode=RGB size=96x32>
# None
# <PIL.Image.Image image mode=RGB size=69x32>
# <PIL.Image.Image image mode=RGB size=110x32>
# None
# <PIL.Image.Image image mode=RGB size=98x32>
# None
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 21
#      13 # The generators use the same arguments as the CLI, only as parameters
#      14 generator = GeneratorFromStrings(
#      15     ['আমি যাবো', "নির্লজ্জ"],
#      16     blur=2,
#      17     random_blur=True,
#      18     language="latin"
#      19 )
# ---> 21 for i, (img, lbl) in enumerate(generator):
#      22     display(img)
#      23     if i > 10:
#
# File ~/Desktop/practice_code/practice_intelsense/TextRecognitionDataGenerator/trdg/generators/from_strings.py:97, in GeneratorFromStrings.__next__(self)
#      96 def __next__(self):
# ---> 97     return self.next()
#
# File ~/Desktop/practice_code/practice_intelsense/TextRecognitionDataGenerator/trdg/generators/from_strings.py:104, in GeneratorFromStrings.next(self)
#     101     raise StopIteration
#     102 self.generated_count += 1
#     103 return (
# --> 104     FakeTextDataGenerator.generate(
#     105         self.generated_count,
#     106         self.strings[(self.generated_count - 1) % len(self.strings)],
#     107         self.fonts[(self.generated_count - 1) % len(self.fonts)],
#     108         None,
#     109         self.size,
#     110         None,
#     111         self.skewing_angle,
#     112         self.random_skew,
#     113         self.blur,
#     114         self.random_blur,
#     115         self.background_type,
#     116         self.distorsion_type,
#     117         self.distorsion_orientation,
#     118         self.is_handwritten,
#     119         0,
#     120         self.width,
#     121         self.alignment,
#     122         self.text_color,
#     123         self.orientation,
#     124         self.space_width,
#     125         self.character_spacing,
#     126         self.margins,
#     127         self.fit,
#     128         self.output_mask,
#     129         self.word_split,
#     130         self.image_dir,
#     131         self.stroke_width,
#     132         self.stroke_fill,
#     133         self.image_mode,
#     134         self.output_bboxes,
#     135     ),
#     136     self.orig_strings[(self.generated_count - 1) % len(self.orig_strings)]
#     137     if self.rtl
#     138     else self.strings[(self.generated_count - 1) % len(self.strings)],
#     139 )
#
# File ~/Desktop/practice_code/practice_intelsense/TextRecognitionDataGenerator/trdg/data_generator.py:133, in FakeTextDataGenerator.generate(cls, index, text, font, out_dir, size, extension, skewing_angle, random_skew, blur, random_blur, background_type, distorsion_type, distorsion_orientation, is_handwritten, name_format, width, alignment, text_color, orientation, space_width, character_spacing, margins, fit, output_mask, word_split, image_dir, stroke_width, stroke_fill, image_mode, output_bboxes)
#     128 if orientation == 0:
#     129     new_width = int(
#     130         distorted_img.size[0]
#     131         * (float(size - vertical_margin) / float(distorted_img.size[1]))
#     132     )
# --> 133     resized_img = distorted_img.resize(
#     134         (new_width, size - vertical_margin), Image.Resampling.LANCZOS
#     135     )
#     136     resized_mask = distorted_mask.resize(
#     137         (new_width, size - vertical_margin), Image.Resampling.NEAREST
#     138     )
#     139     background_width = width if width > 0 else new_width + horizontal_margin
#
# File ~/miniconda3/envs/ocr-gen/lib/python3.10/site-packages/PIL/Image.py:2199, in Image.resize(self, size, resample, box, reducing_gap)
#    2197 if self.mode in ["LA", "RGBA"] and resample != Resampling.NEAREST:
#    2198     im = self.convert({"LA": "La", "RGBA": "RGBa"}[self.mode])
# -> 2199     im = im.resize(size, resample, box)
#    2200     return im.convert(self.mode)
#    2202 self.load()
#
# File ~/miniconda3/envs/ocr-gen/lib/python3.10/site-packages/PIL/Image.py:2222, in Image.resize(self, size, resample, box, reducing_gap)
#    2210         self = (
#    2211             self.reduce(factor, box=reduce_box)
#    2212             if callable(self.reduce)
#    2213             else Image.reduce(self, factor, box=reduce_box)
#    2214         )
#    2215         box = (
#    2216             (box[0] - reduce_box[0]) / factor_x,
#    2217             (box[1] - reduce_box[1]) / factor_y,
#    2218             (box[2] - reduce_box[0]) / factor_x,
#    2219             (box[3] - reduce_box[1]) / factor_y,
#    2220         )
# -> 2222 return self._new(self.im.resize(size, resample, box))
#
# ValueError: height and width must be > 0
